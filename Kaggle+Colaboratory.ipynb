# %% [markdown]
# <a href="https://colab.research.google.com/github/JeffAirData/Kaggle-Colaboratory/blob/main/Kaggle%2BColaboratory.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Dica de como conectar Goggle.colab ao Kaggle de @IgorLucci: https://www.youtube.com/watch?v=LLD6nQR7iz0
#
# Acompanhe para mais: https://www.youtube.com/@IgorLucci

# %%
from google.colab import files

# %%
files.upload()
# Out:
#      <input type="file" id="files-bc2fb03e-85f8-4c5c-931a-39c18c4f754f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-bc2fb03e-85f8-4c5c-931a-39c18c4f754f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install kaggle -q

# %%
# !mkdir ~/.kaggle
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists

# %%
# !cp kaggle.json ~/.kaggle/

# %%
# !chmod 600~/.kaggle/kaggle.jason
# Out:
# chmod: missing operand after ‘600~/.kaggle/kaggle.jason’
# Try 'chmod --help' for more information.

# %%
# !kaggle datasets list
# Out:
# ...
# ref                                                      title                                        size  lastUpdated          downloadCount  voteCount  usabilityRating
# -------------------------------------------------------  ------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# nelgiriyewithana/apple-quality                           Apple Quality                               170KB  2024-01-11 14:31:07           3708         93  1.0
# hummaamqaasim/jobs-in-data                               Jobs and Salaries in Data Science            76KB  2023-12-25 20:03:32          10018        197  1.0
# fekihmea/sales-store-overview                            Sales Store overview                          2KB  2024-01-20 11:10:10            903         25  1.0
# shashwatwork/depression-and-mental-health-data-analysis  Depression and Mental Health Data Analysis    7KB  2024-01-14 16:24:08            950         23  0.9411765
# ...

# %%
# %cd /content/

# !kaggle competitions download -c titanic
# Out:
# /content
# ...
#   0% 0.00/34.1k [00:00<?, ?B/s]
# 100% 34.1k/34.1k [00:00<00:00, 30.7MB/s]

# %%
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# !unzip titanic.zip -d titanic
# Out:
# Archive:  titanic.zip
#   inflating: titanic/gender_submission.csv
#   inflating: titanic/test.csv
#   inflating: titanic/train.csv

# %%
import pandas as pd

# %%
pd.read_csv('/content/titanic/test.csv')
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...
